# %% [markdown]
# ## Machine Learning - K Means Clustering

# %% [markdown]
# This project I will use KMeans Clustering to cluster Universities into two groups, Private and Public.

# %% [markdown]
# ### The Data
#
# our data frame with 777 observations on the following 18 variables.
#
# * Private A factor with levels No and Yes indicating private or public university
# * Apps Number of applications received
# * Accept Number of applications accepted
# * Enroll Number of new students enrolled
# * Top10perc Pct. new students from the top 10% of H.S. class
# * Top25perc Pct. new students from the top 25% of H.S. class
# * F.Undergrad Number of fulltime undergraduates
# * P.Undergrad Number of parttime undergraduates
# * Outstate Out-of-state tuition
# * Room.Board Room and board costs
# * Books Estimated book costs
# * Personal Estimated personal spending
# * Ph.D. Pct. of faculty with Ph.D.’s
# * Terminal Pct. of faculty with terminal degree
# * S.F.Ratio Student/faculty ratio
# * perc.alumni Pct. alumni who donate
# * Expend Instructional expenditure per student
# * Grad.Rate Graduation rate

# %% [markdown]
# ### Import Libraries

# %%
# starting with importing libariraies 

import numpy as np
import pandas as pd

# %%
# importing data visualization libraries 

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### Get the Data

# %%
# read CSV method, and set the first column as the index

df = pd.read_csv('College_Data',index_col=0)

# %%
df
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 777 entries, Abilene Christian University to York College of Pennsylvania
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Private      777 non-null    object
#  1   Apps         777 non-null    int64
#  2   Accept       777 non-null    int64
#  3   Enroll       777 non-null    int64
#  4   Top10perc    777 non-null    int64
#  5   Top25perc    777 non-null    int64
#  6   F.Undergrad  777 non-null    int64
#  7   P.Undergrad  777 non-null    int64
#  8   Outstate     777 non-null    int64
#  9   Room.Board   777 non-null    int64
#  10  Books        777 non-null    int64
#  11  Personal     777 non-null    int64
#  12  PhD          777 non-null    int64
#  13  Terminal     777 non-null    int64
#  14  S.F.Ratio    777 non-null    float64
#  15  perc.alumni  777 non-null    int64
#  16  Expend       777 non-null    int64
# ...

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# ### EDA

# %% [markdown]
# **creating a scatterplot of 'Grad.Rate' vs 'Room.Board'
# where the points are colored by the column 'Private'=hue**

# %%
sns.lmplot (x='Room.Board', y='Grad.Rate',data=df, hue='Private')

# %%
# adding more arguments to our plot

sns.lmplot(x='Room.Board', y='Grad.Rate',data=df, hue='Private',
           fit_reg=False, palette='coolwarm', aspect=1 )

# %% [markdown]
# **Create a scatterplot of 'F.Undergrad' vs 'Outstate'
# where the points are colored by the column 'Private'=hue**

# %%
sns.lmplot (x='Outstate', y='F.Undergrad',data=df, hue='Private')

# %%
# adding more arguments to the code 

sns.set_style('whitegrid')

sns.lmplot(x='Outstate', y='F.Undergrad',data=df, hue='Private',
           palette='coolwarm',aspect=1,fit_reg=False)

# %% [markdown]
# By comparing out-of-state tuition and the number of undergrads, private and public schools show distinct differences.
#
# Public schools have a clear cutoff point for their tuition, and generally have a larger number of undergraduates compared to
# private schools,
#
# Private schools have significantly higher tuition costs, which aligns with the common characteristics of private schools being smaller and more expensive, and public schools being larger with lower costs.

# %% [markdown]
# **create a stacked histogram showing Out of 'State Tuition' based on the 'Private' column.**
#
# I will be using 'sns.FacetGrid', by using two instances of pandas.plot(kind='hist').

# %%
sns.set_style('darkgrid')

g = sns.FacetGrid(df,hue="Private")
g = g.map(plt.hist,'Outstate',bins=20)

# %%
# adding more arguments 

sns.set_style('darkgrid')
plt.figure(figsize=(12,8))

g = sns.FacetGrid(df,hue="Private",palette='coolwarm',aspect=2)
g = g.map(plt.hist,'Outstate',bins=50,alpha=0.7)

# %% [markdown]
# **create a similar histogram for the 'Grad.Rate' column**

# %%
sns.set_style('darkgrid')

g = sns.FacetGrid(df,hue="Private")
g = g.map(plt.hist,'Grad.Rate',bins=20)

# %%
# adding arguments 

sns.set_style('darkgrid')
plt.figure(figsize=(12,8))

g = sns.FacetGrid(df,hue="Private",palette='magma',aspect=2)
g = g.map(plt.hist,'Grad.Rate',bins=50,alpha=0.7)

# %% [markdown]
# notice here there is a  private school with a graduation rate of higher than 100%.
# What is the name of that school?
#
# let's try to grab it

# %%
df[df['Grad.Rate']>100]
# Out:
#                   Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# Cazenovia College     Yes  3847    3433     527          9         35
#
#                    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# Cazenovia College         1010           12      9384        4840    600
#
#                    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# Cazenovia College       500   22        47       14.3           20    7697
#
#                    Grad.Rate
# Cazenovia College        118

# %% [markdown]
# we can see they have a grade rate of 118%, which is obviously wrong, so I will set the rate to 100% to make it fit our dataset.

# %%
df['Grad.Rate']['Cazenovia College'] = 100

# it will show us a warning that we are changing a value in our dataframe
# Out:
# /var/folders/z0/xpcqj0kn51bff0j0jmzhrx080000gn/T/ipykernel_6726/2317331491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Grad.Rate']['Cazenovia College'] = 100

# %%
# now let's check again and see the 'Cazenovia College' rate

sns.set_style('darkgrid')
plt.figure(figsize=(12,8))

g = sns.FacetGrid(df,hue="Private",palette='magma',aspect=2)
g = g.map(plt.hist,'Grad.Rate',bins=50,alpha=0.7)

# %% [markdown]
# ### K Means Cluster Creation

# %% [markdown]
# Now it is time to create the Cluster labels
#
# **Import KMeans from SciKit Learn**

# %%
from sklearn.cluster import KMeans

# %%
# creat an instance of KMenas model with 2 clusters 

kmeans = KMeans(n_clusters=2)

# %%
# fit the model

kmeans.fit(df.drop('Private',axis=1))
# Out:
# /Users/alex/anaconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %% [markdown]
# #### N: Note that we dont do a train to split here because that wouldn't make sense on an unsupervised learning algorithms as we don't actually have labels to split

# %%
# cluster center vectors

kmeans.cluster_centers_
# Out:
# array([[1.03631389e+04, 6.55089815e+03, 2.56972222e+03, 4.14907407e+01,
#         7.02037037e+01, 1.30619352e+04, 2.46486111e+03, 1.07191759e+04,
#         4.64347222e+03, 5.95212963e+02, 1.71420370e+03, 8.63981481e+01,
#         9.13333333e+01, 1.40277778e+01, 2.00740741e+01, 1.41705000e+04,
#         6.75925926e+01],
#        [1.81323468e+03, 1.28716592e+03, 4.91044843e+02, 2.53094170e+01,
#         5.34708520e+01, 2.18854858e+03, 5.95458894e+02, 1.03957085e+04,
#         4.31136472e+03, 5.41982063e+02, 1.28033632e+03, 7.04424514e+01,
#         7.78251121e+01, 1.40997010e+01, 2.31748879e+01, 8.93204634e+03,
#         6.50926756e+01]])

# %% [markdown]
# ### Evaluation

# %% [markdown]
# there is no perfect way to evaluate clustering if you don't have the labels
#
# **for this dataset I will create a new column for df called 'Cluster', which is a 1 for a Private school, and a 0 for a public school**

# %%
def converter(cluster):
    if cluster=='Yes':
        return 1
    else:
        return 0

# %%
df['Cluster'] = df['Private'].apply(converter)

# %%
df.head()

# we should find the 'Cluster' column initiated, shich aligns with 'Private' column.
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
#                               Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# **create a confusion matrix and classification report to see how well the Kmeans clustering worked without being given any labels**

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(df['Cluster'],kmeans.labels_))
# Out:
# [[ 74 138]
#  [ 34 531]]

# %%
print(classification_report(df['Cluster'],kmeans.labels_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.35      0.46       212
#            1       0.79      0.94      0.86       565
#
#     accuracy                           0.78       777
#    macro avg       0.74      0.64      0.66       777
# weighted avg       0.76      0.78      0.75       777

# %% [markdown]
# ### - - - - The end - - - -
